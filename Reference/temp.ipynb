# %%
#OOPS 

import pandas as pd
import numpy as np

class refer:
    
    codes="State_UT_Code.csv"
    
    def __init__(self,file):
        self.file=file
    
    def sut_code(self):

# %%
file="G:\GitClone\Project at GIT\Tuberclosis Risk\TB-Risk\Demography\Demography_2021_MOD.csv"
df=pd.read_csv(file,index_col=False)
df
# Out:
#     Unnamed: 0  SL. NO.                     STATE_UT   POPULATION      AREA  \
# 0            0        1                Uttar Pradesh  199812341.0  240928.0
# 1            1        2                  Maharashtra  112374333.0  307713.0
# 2            2        3                        Bihar  104099452.0   94163.0
# 3            3        4                  West Bengal   91276115.0   88752.0
# 4            4        5               Madhya Pradesh   72626809.0  308245.0
# 5            5        6                   Tamil Nadu   72147030.0  130058.0
# 6            6        7                    Rajasthan   68548437.0  342239.0
# 7            7        8                    Karnataka   61095297.0  191791.0
# 8            8        9                      Gujarat   60439692.0  196024.0
# 9            9       10               Andhra Pradesh   49577103.0  162968.0
# 10          10       11                       Odisha   41974218.0  155707.0
# ...
